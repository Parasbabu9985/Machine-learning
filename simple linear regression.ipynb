# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
dataset=pd.read_csv("cgpa_package.csv")
dataset.head(5)
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
dataset.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
# independent dataset two dimentional hona chahiye

# %%
x=dataset[["cgpa"]]
y=dataset["package"]
#x.ndim

# %%
sns.scatterplot(x='cgpa',y='package',data=dataset)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=100)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr= LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.9859187290955509

# %%
#6.89	3.26

# %%
c #ye m and c kee value return karta hai y=m*x+c
# Out:
# C:\Users\Paras\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2.77927406])

# %%
lr.coef_
# Out:
# array([0.494874])

# %%
lr.intercept_
# Out:
# np.float64(-0.6304078366737991)

# %%
0.494874*6.89-0.6304078366737991 # direct formula se bhee same hi hai
# Out:
# 2.7792740233262005

# %%
y_pred=lr.predict(x)

# %%
sns.scatterplot(x='cgpa',y='package',data=dataset)
plt.plot(dataset[['cgpa']],y_pred,color='red')
plt.show
plt.legend(['org data','predicted line'])
