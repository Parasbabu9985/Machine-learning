# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
# bases on age to pridict purchase

# %%
dataset=pd.read_csv("Social_Network_Ads_100.csv")

dataset.drop(columns=["EstimatedSalary"],inplace=True)
dataset.head(5)
# Out:
#    Age  Purchased
# 0   19          0
# 1   35          0
# 2   26          0
# 3   27          0
# 4   27          0

# %%
plt.figure(figsize=(4,3))
sns.scatterplot(x="Age",y="Purchased",data=dataset)
plt.show()

# %%
x=dataset[["Age"]]
y=dataset["Purchased"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 92.3076923076923

# %%
lr.predict([[60]])
# Out:
# C:\Users\Paras\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
plt.figure(figsize=(4,3))
sns.scatterplot(x="Age",y="Purchased",data=dataset)
sns.lineplot(x="Age",y=lr.predict(x),data=dataset,color='red')
plt.show()
