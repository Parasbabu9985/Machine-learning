# %% [markdown]
# # for placement pridicton

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("placement.csv")
dataset.head(5)
# Out:
#    cgpa  score  placed
# 0  8.14   6.52       1
# 1  6.17   5.17       0
# 2  8.27   8.86       1
# 3  6.88   7.27       1
# 4  7.52   7.30       1

# %%
plt.figure(figsize=(4,3))
sns.scatterplot(x="cgpa",y="score",data=dataset,hue="placed") # hue for classification of palaced
plt.show()

# %%
x=dataset.iloc[:,:-1]
y=dataset["placed"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 100.0

# %%
lr.predict([[8.14,	6.52	]])
# Out:
# C:\Users\Paras\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
# isme decision making chart banate hai isme algorithm kam kartree hai
# 1/1+e^-x

# %%
from mlxtend.plotting import plot_decision_regions

# %%
# ise numpy  e convert karTE HAI, clf =lr yani model ka naam

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=lr)
plt.show()
# Out:
# C:\Users\Paras\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
